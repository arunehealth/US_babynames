# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import seaborn as sns

# %%
n_n = pd.read_csv('NationalNames.csv')

# %%
n_n.head(50)
# Out:
#     Id       Name  Year Gender  Count
# 0    1       Mary  1880      F   7065
# 1    2       Anna  1880      F   2604
# 2    3       Emma  1880      F   2003
# 3    4  Elizabeth  1880      F   1939
# 4    5     Minnie  1880      F   1746
# 5    6   Margaret  1880      F   1578
# 6    7        Ida  1880      F   1472
# 7    8      Alice  1880      F   1414
# 8    9     Bertha  1880      F   1320
# 9   10      Sarah  1880      F   1288
# 10  11      Annie  1880      F   1258
# 11  12      Clara  1880      F   1226
# 12  13       Ella  1880      F   1156
# 13  14   Florence  1880      F   1063
# 14  15       Cora  1880      F   1045
# 15  16     Martha  1880      F   1040
# 16  17      Laura  1880      F   1012
# 17  18     Nellie  1880      F    995
# 18  19      Grace  1880      F    982
# 19  20     Carrie  1880      F    949
# 20  21      Maude  1880      F    858
# 21  22      Mabel  1880      F    808
# 22  23     Bessie  1880      F    796
# 23  24     Jennie  1880      F    793
# ...

# %%
n_n.tail(2)
# Out:
#               Id   Name  Year Gender  Count
# 1825431  1825432  Zyran  2014      M      5
# 1825432  1825433  Zyrin  2014      M      5

# %%
n_n.describe()
# Out:
#                  Id          Year         Count
# count  1.825433e+06  1.825433e+06  1.825433e+06
# mean   9.127170e+05  1.972620e+03  1.846879e+02
# std    5.269573e+05  3.352891e+01  1.566711e+03
# min    1.000000e+00  1.880000e+03  5.000000e+00
# 25%    4.563590e+05  1.949000e+03  7.000000e+00
# 50%    9.127170e+05  1.982000e+03  1.200000e+01
# 75%    1.369075e+06  2.001000e+03  3.200000e+01
# max    1.825433e+06  2.014000e+03  9.968000e+04

# %%
n_n.isnull().sum()
# Out:
# Id        0
# Name      0
# Year      0
# Gender    0
# Count     0
# dtype: int64

# %%
n_n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1825433 entries, 0 to 1825432
# Data columns (total 5 columns):
# Id        int64
# Name      object
# Year      int64
# Gender    object
# Count     int64
# dtypes: int64(3), object(2)
# memory usage: 69.6+ MB

# %% [markdown]
# #### checking the unique names

# %% [markdown]
# ###checking for the number of unique instances

# %%
n_n['Name'].unique()
# Out:
# array(['Mary', 'Anna', 'Emma', ..., 'Zijun', 'Zilas', 'Zirui'],
#       dtype=object)

# %%
len(n_n['Name'].unique())
# Out:
# 93889

# %%
n_n['Year'].unique()
# Out:
# array([1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890,
#        1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901,
#        1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912,
#        1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923,
#        1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934,
#        1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945,
#        1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956,
#        1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#        1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#        1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014], dtype=int64)

# %%
len(n_n['Name'].unique())
# Out:
# 93889

# %%
n_n['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
bread = n_n['Name'].unique()

# %% [markdown]
# ###to find out if "Mary" exists in the dataset

# %%
'Eva'in n_n.Name.values

# %%
n_n.Name[n_n.Name == Mary].count()

# %% [markdown]
# ###Locking the column "Name" with relation to a particualr name. Here the name locked is Mary

# %%
mary = n_n[n_n['Name']=="Mary"].count()

# %%
mary
# Out:
#               Id  Name  Year Gender  Count
# 0              1  Mary  1880      F   7065
# 1273        1274  Mary  1880      M     27
# 2000        2001  Mary  1881      F   6919
# 3238        3239  Mary  1881      M     29
# 3935        3936  Mary  1882      F   8148
# 5277        5278  Mary  1882      M     30
# 6062        6063  Mary  1883      F   8012
# 7407        7408  Mary  1883      M     32
# 8146        8147  Mary  1884      F   9217
# 9610        9611  Mary  1884      M     36
# 10443      10444  Mary  1885      F   9128
# 11910      11911  Mary  1885      M     38
# 12737      12738  Mary  1886      F   9890
# 14323      14324  Mary  1886      M     32
# 15129      15130  Mary  1887      F   9888
# 16671      16672  Mary  1887      M     47
# 17502      17503  Mary  1888      F  11754
# 19223      19224  Mary  1888      M     50
# 20153      20154  Mary  1889      F  11648
# 21893      21894  Mary  1889      M     41
# 22743      22744  Mary  1890      F  12078
# ...

# %%
n_n.loc[n_n['Name']=="Mary"]
# Out:
#               Id  Name  Year Gender  Count
# 0              1  Mary  1880      F   7065
# 1273        1274  Mary  1880      M     27
# 2000        2001  Mary  1881      F   6919
# 3238        3239  Mary  1881      M     29
# 3935        3936  Mary  1882      F   8148
# 5277        5278  Mary  1882      M     30
# 6062        6063  Mary  1883      F   8012
# 7407        7408  Mary  1883      M     32
# 8146        8147  Mary  1884      F   9217
# 9610        9611  Mary  1884      M     36
# 10443      10444  Mary  1885      F   9128
# 11910      11911  Mary  1885      M     38
# 12737      12738  Mary  1886      F   9890
# 14323      14324  Mary  1886      M     32
# 15129      15130  Mary  1887      F   9888
# 16671      16672  Mary  1887      M     47
# 17502      17503  Mary  1888      F  11754
# 19223      19224  Mary  1888      M     50
# 20153      20154  Mary  1889      F  11648
# 21893      21894  Mary  1889      M     41
# 22743      22744  Mary  1890      F  12078
# ...

# %%
f_n_n = n_n[n_n['Gender']=="F"]

# %%
f_n_n.describe()
# Out:
#                  Id          Year         Count
# count  1.081683e+06  1.081683e+06  1.081683e+06
# mean   9.155025e+05  1.973355e+03  1.544542e+02
# std    5.164205e+05  3.285129e+01  1.204542e+03
# min    1.000000e+00  1.880000e+03  5.000000e+00
# 25%    4.839075e+05  1.952000e+03  7.000000e+00
# 50%    9.128810e+05  1.982000e+03  1.100000e+01
# 75%    1.362606e+06  2.001000e+03  3.100000e+01
# max    1.811456e+06  2.014000e+03  9.968000e+04

# %% [markdown]
# ####to lock multiple conditions example all Marys who are Females//
# mf_n_n is the file that contains all Female Marys

# %%
mf_n_n = n_n.loc[(n_n['Name'] == "Mary") & (n_n['Gender'] == "F")]

# %%
mf_n_n
# Out:
#               Id  Name  Year Gender  Count
# 0              1  Mary  1880      F   7065
# 2000        2001  Mary  1881      F   6919
# 3935        3936  Mary  1882      F   8148
# 6062        6063  Mary  1883      F   8012
# 8146        8147  Mary  1884      F   9217
# 10443      10444  Mary  1885      F   9128
# 12737      12738  Mary  1886      F   9890
# 15129      15130  Mary  1887      F   9888
# 17502      17503  Mary  1888      F  11754
# 20153      20154  Mary  1889      F  11648
# 22743      22744  Mary  1890      F  12078
# 25438      25439  Mary  1891      F  11703
# 28098      28099  Mary  1892      F  13173
# 31019      31020  Mary  1893      F  12784
# 33850      33851  Mary  1894      F  13151
# 36791      36792  Mary  1895      F  13446
# 39840      39841  Mary  1896      F  13811
# 42931      42932  Mary  1897      F  13413
# 45959      45960  Mary  1898      F  14406
# 49223      49224  Mary  1899      F  13172
# 52265      52266  Mary  1900      F  16707
# ...

# %%
mf_n_n.dtypes
# Out:
# Id         int64
# Name      object
# Year       int64
# Gender    object
# Count      int64
# dtype: object

# %%
mary = n_n[n_n['Name'] == "Mary"].groupby('Year').Count.sum()

# %%
mary.plot()

# %%
mary
# Out:
# Year
# 1880     7092
# 1881     6948
# 1882     8178
# 1883     8044
# 1884     9253
# 1885     9166
# 1886     9922
# 1887     9935
# 1888    11804
# 1889    11689
# 1890    12113
# 1891    11742
# 1892    13223
# 1893    12839
# 1894    13199
# 1895    13493
# 1896    13868
# 1897    13476
# 1898    14456
# 1899    13222
# 1900    16782
# 1901    13194
# 1902    14542
# 1903    14338
# 1904    15020
# 1905    16135
# 1906    16446
# 1907    17650
# 1908    18745
# 1909    19339
#         ...
# 1985     9306
# 1986     8550
# 1987     8464
# 1988     8556
# 1989     8716
# 1990     8709
# 1991     8788
# 1992     8477
# 1993     8128
# 1994     7756
# 1995     7446
# 1996     6957
# 1997     6639
# 1998     6443
# 1999     6370
# 2000     6192
# 2001     5737
# 2002     5462
# 2003     5018
# 2004     4834
# 2005     4457
# 2006     4091
# 2007     3683
# 2008     3490
# 2009     3154
# 2010     2862
# 2011     2701
# 2012     2571
# 2013     2632
# 2014     2616
# ...

# %%
mary = dict()
years = range (1880,1890)
for each_year in years:
    each_year_data = n_n[n_n['Year'] == each_year]
    mary[each_year] = dict()
    for index, row in each_year_data.iterrows():
        mary[each_year][row['Name']] = row['Count']

# %% [markdown]
# ###n_n.groupby(['Year','Name']).size().reset_index(name="Mary")

# %%
n_n['Year'] = n_n['Year'] = n_n.pd.to_datetime
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-51f1a76b7ec9> in <module>()
# ----> 1 n_n['Year'] = n_n['Year'] = n_n.pd.to_datetime
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'pd'

# %% [markdown]
# #we have to learn to coinvert and split a date time function

# %%
n_n.dtypes
# Out:
# Id                 int64
# Name              object
# Year      datetime64[ns]
# Gender            object
# Count              int64
# dtype: object

# %%
n_n.head(50)
# Out:
#     Id       Name                          Year Gender  Count
# 0    1       Mary 1970-01-01 00:00:00.000001880      F   7065
# 1    2       Anna 1970-01-01 00:00:00.000001880      F   2604
# 2    3       Emma 1970-01-01 00:00:00.000001880      F   2003
# 3    4  Elizabeth 1970-01-01 00:00:00.000001880      F   1939
# 4    5     Minnie 1970-01-01 00:00:00.000001880      F   1746
# 5    6   Margaret 1970-01-01 00:00:00.000001880      F   1578
# 6    7        Ida 1970-01-01 00:00:00.000001880      F   1472
# 7    8      Alice 1970-01-01 00:00:00.000001880      F   1414
# 8    9     Bertha 1970-01-01 00:00:00.000001880      F   1320
# 9   10      Sarah 1970-01-01 00:00:00.000001880      F   1288
# 10  11      Annie 1970-01-01 00:00:00.000001880      F   1258
# 11  12      Clara 1970-01-01 00:00:00.000001880      F   1226
# 12  13       Ella 1970-01-01 00:00:00.000001880      F   1156
# 13  14   Florence 1970-01-01 00:00:00.000001880      F   1063
# ...

# %%
n_n["Year"] = n_n["Year"].apply(lambda x: x.split(" ")[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-5107939964b7> in <module>()
# ----> 1 n_n["Year"] = n_n["Year"].apply(lambda x: x.split(" ")[0])
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-67-5107939964b7> in <lambda>(x)
# ----> 1 n_n["Year"] = n_n["Year"].apply(lambda x: x.split(" ")[0])
#
# AttributeError: 'Timestamp' object has no attribute 'split'

# %%
n_n['Year'] = n_n.Year.string.slice([-4:-1])
# Out:
#   File "<ipython-input-60-0dbc2d403fee>", line 1
#     n_n['Year'] = n_n.Year.string.slice([-4:-1])
#                                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ####Finding the most common names by popularity

# %%
names_dict = dict()
for index, row in n_n.iterrows():
    if row['Name'] not in names_dict:
        names_dict[row['Name']] = row['Count']
    else:
            names_dict[row['Name']] += row['Count']

# %%
top_10 = Counter(names_dict).most_common (20)
print ("Top 10 names = ")
for arun in top_10:
    print (arun[0])
# Out:
# Top 10 names =
# James
# John
# Robert
# Michael
# Mary
# William
# David
# Joseph
# Richard
# Charles
# Thomas
# Christopher
# Daniel
# Elizabeth
# Patricia
# Matthew
# Jennifer
# George
# Linda
# Barbara

# %% [markdown]
# print ("Least used 10 names= ")
# for pair in Counter(names_dict).most_common ()[:-10:-1]:
#     print (pair[0])

# %%
s_n = pd.read_csv('StateNames.csv')

# %%
s_n.head(2)
# Out:
#    Id   Name  Year Gender State  Count
# 0   1   Mary  1910      F    AK     14
# 1   2  Annie  1910      F    AK     12

# %%
n_n.merge('name',how = 'inner', left_on = 'n_n', right_on = 's_n')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-ad2d11969ca0> in <module>()
# ----> 1 n_n.merge('name',how = 'inner', left_on = 'n_n', right_on = 's_n')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    5368                      right_on=right_on, left_index=left_index,
#    5369                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 5370                      copy=copy, indicator=indicator, validate=validate)
#    5371
#    5372     def round(self, decimals=0, *args, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...
